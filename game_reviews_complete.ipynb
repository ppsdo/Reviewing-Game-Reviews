# %% [markdown]
# # Reviewing IGN's Game Reviews
#
# Do reviews in which a higher a score was given tend to have a more positive sentiment?
#
# Approach: for each videogame review from IGN on YouTube, compare the score given at the end with various metrics of sentiment such as the comment section and likes-to-dislikes ratio.
#
# Generally, there are 3 problems that must be solved:
# 1. Getting the data.
# 2. Cleaning the data.
# 3. Performing the analysis

# %% [markdown]
# ## Part 1: Getting the data
#
# This includes using the YouTube API to access each video and the associated data from their "Game Reviews" playlist.

# %%
import streamlit as st
import pandas as pd

df = pd.read_csv("review_scores.csv")
df
# Out:
#       index                                      video title  score  \
# 0         0                 detective-pikachu-returns-review    6.0
# 1         1                ea-sports-fc-24-for-switch-review    4.0
# 2         2                          forza-motorsport-review    8.0
# 3         3                        station-to-station-review    8.0
# 4         4                    assassins-creed-mirage-review    8.0
# ...     ...                                              ...    ...
# 2124   2124  state-of-decay-year-one-survival-edition-review    8.9
# 2125   2125           the-evil-within-the-consequence-review    7.0
# 2126   2126         broken-age-the-complete-adventure-review   -1.0
# 2127   2127                          broken-age-act-2-review    9.0
# 2128   2128          assassins-creed-chronicles-china-review    6.4
#
#               source                                     parsed title  \
# 0     direct article                 detective-pikachu-returns-review
# 1     direct article                ea-sports-fc-24-for-switch-review
# 2     direct article                          forza-motorsport-review
# 3     direct article                        station-to-station-review
# 4     direct article                    assassins-creed-mirage-review
# ...              ...                                              ...
# 2124  direct article  state-of-decay-year-one-survival-edition-review
# 2125  direct article           the-evil-within-the-consequence-review
# 2126          search         broken-age-the-complete-adventure-review
# 2127  direct article                          broken-age-act-2-review
# 2128  direct article          assassins-creed-chronicles-china-review
#
#                                                     url
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2124                                                NaN
# 2125                                                NaN
# 2126  https://www.ign.com/games/broken-age-the-compl...
# 2127                                                NaN
# 2128                                                NaN
#
# [2129 rows x 6 columns]
