# %%
from pathlib import Path
import sys

sys.path.append(str(Path().absolute().parent))
# sys.path

# %% [markdown]
# # Ingestion
#
# Includes:
# - reading from `playlist.csv`
# - making an API call to `youtube.videos.list()`
# - logging and storing the API calls

# %% [markdown]
# ## Reading from the `playlist.csv`
#
# Only read, do not poll.

# %%
import pandas as pd

def read_playlist_csv(source="../playlist/db/playlist.csv"):
    df = pd.read_csv(source)
    return df

# %%
df = read_playlist_csv()
df.head()
# Out:
#                    kind                         etag  \
# 0  youtube#playlistItem  jr_adfcvhrU9UD2kp5b8Xh2644U
# 1  youtube#playlistItem  ePHYBy6OhjiL1IClvuazdjoB79Q
# 2  youtube#playlistItem  kAGScijE-ZDpBZGHMQgwF1nDjFo
# 3  youtube#playlistItem  QVZITUKMom6idlvcdtWyYzcg1Vk
# 4  youtube#playlistItem  DwbGeylu7C63IzykIrHvrFtDymA
#
#                                                   id   snippet.publishedAt  \
# 0  UExyYUZid0NvaXNKQlRsMG9YbjhVb1VhbTVIWFdVWjdFUy...  2016-04-30T00:30:14Z
# 1  UExyYUZid0NvaXNKQlRsMG9YbjhVb1VhbTVIWFdVWjdFUy...  2016-04-27T02:00:23Z
# 2  UExyYUZid0NvaXNKQlRsMG9YbjhVb1VhbTVIWFdVWjdFUy...  2016-04-26T15:30:09Z
# 3  UExyYUZid0NvaXNKQlRsMG9YbjhVb1VhbTVIWFdVWjdFUy...  2016-04-22T02:30:15Z
# 4  UExyYUZid0NvaXNKQlRsMG9YbjhVb1VhbTVIWFdVWjdFUy...  2016-04-22T01:00:11Z
#
#           snippet.channelId                                  snippet.title  \
# 0  UCKy1dAqELo0zrOtPkf0eTMw                              Alienation Review
# 1  UCKy1dAqELo0zrOtPkf0eTMw  The Walking Dead: Michonne - Episode 3 Review
# 2  UCKy1dAqELo0zrOtPkf0eTMw                                 Severed Review
# 3  UCKy1dAqELo0zrOtPkf0eTMw              Battlefleet Gothic: Armada Review
# 4  UCKy1dAqELo0zrOtPkf0eTMw           1979 Revolution: Black Friday Review
#
#                                  snippet.description snippet.channelTitle  \
# 0  Housemarque's follow-up to Dead Nation is fast...                  IGN
# 1  The third and final episode of Michonne's jour...                  IGN
# 2  Severed starts as a fun take on touch combat, ...                  IGN
# 3  It's not always clear what's going on, but thi...                  IGN
# 4  1979 Revolution: Black Friday turns an overloo...                  IGN
#
#                    snippet.playlistId  snippet.position  ...  \
# 0  PLraFbwCoisJBTl0oXn8UoUam5HXWUZ7ES              1600  ...
# 1  PLraFbwCoisJBTl0oXn8UoUam5HXWUZ7ES              1601  ...
# 2  PLraFbwCoisJBTl0oXn8UoUam5HXWUZ7ES              1602  ...
# 3  PLraFbwCoisJBTl0oXn8UoUam5HXWUZ7ES              1603  ...
# 4  PLraFbwCoisJBTl0oXn8UoUam5HXWUZ7ES              1604  ...
#
#   snippet.thumbnails.maxres.height snippet.videoOwnerChannelTitle  \
# 0                            720.0                            IGN
# 1                            720.0                            IGN
# 2                            720.0                            IGN
# 3                            720.0                            IGN
# 4                            720.0                            IGN
#
#   snippet.videoOwnerChannelId contentDetails.videoPublishedAt  \
# 0    UCKy1dAqELo0zrOtPkf0eTMw            2016-04-30T00:30:01Z
# 1    UCKy1dAqELo0zrOtPkf0eTMw            2016-04-27T02:00:01Z
# 2    UCKy1dAqELo0zrOtPkf0eTMw            2016-04-26T15:30:00Z
# 3    UCKy1dAqELo0zrOtPkf0eTMw            2016-04-22T02:30:01Z
# 4    UCKy1dAqELo0zrOtPkf0eTMw            2016-04-22T01:00:00Z
#
#                           meta.kind                    meta.etag  \
# 0  youtube#playlistItemListResponse  OR2Yc_htGAvUDyCLBQaF_SyzLHc
# 1  youtube#playlistItemListResponse  OR2Yc_htGAvUDyCLBQaF_SyzLHc
# 2  youtube#playlistItemListResponse  OR2Yc_htGAvUDyCLBQaF_SyzLHc
# 3  youtube#playlistItemListResponse  OR2Yc_htGAvUDyCLBQaF_SyzLHc
# 4  youtube#playlistItemListResponse  OR2Yc_htGAvUDyCLBQaF_SyzLHc
#
#                                   meta.nextPageToken  \
# 0  EAAaMVBUOkNQSU1JaEEyTnpneVFrRkZORVV5T1RaRE1rRT...
# 1  EAAaMVBUOkNQSU1JaEEyTnpneVFrRkZORVV5T1RaRE1rRT...
# 2  EAAaMVBUOkNQSU1JaEEyTnpneVFrRkZORVV5T1RaRE1rRT...
# 3  EAAaMVBUOkNQSU1JaEEyTnpneVFrRkZORVV5T1RaRE1rRT...
# 4  EAAaMVBUOkNQSU1JaEEyTnpneVFrRkZORVV5T1RaRE1rRT...
#
#   meta.pageInfo.totalResults  meta.pageInfo.resultsPerPage  meta.requestNumber
# 0                       2182                            50                 123
# 1                       2182                            50                 123
# 2                       2182                            50                 123
# 3                       2182                            50                 123
# 4                       2182                            50                 123
#
# [5 rows x 38 columns]

# %% [markdown]
# ## Downloading data on each video
#
# Call `youtube.videos().list()`.
#
# Also some helpful logging functions.

# %%
# add time requested to the received response
from datetime import datetime, timezone

# just use utc time. "central"
def get_current_time(timezone=timezone.utc):
    now = datetime.now(timezone)
    return now

def serialize_time(dt):
    return dt.isoformat()

def deserialize_datetime_string(dt_string):
    return dt_string.fromisoformat()

# init/reset response.csv. careful with this function.
def reset_response_csv(target="./db/response.csv"):
    '''
    Writes to target csv a dataframe with only columns/headers, no rows.
    Returns the dataframe used to write to the csv.
    
    Each record is a request made and received from the request_video() function.
    '''
    # dummy for keys, copied over from request_video()
    params = {
            "part": 1,
            "id": 2,
            "maxResults": 3
        }
    headers_df = pd.DataFrame(columns=[
        'requestNumber',
        'timeSent',
        'timeReceived',
        *[f'params.{k}' for k in params.keys()]
    ])
    
    headers_df.to_csv(target, index=False)
    return headers_df

# edit response.csv
def append_response_csv(data_dict, target="./db/response.csv"):
    df = pd.json_normalize(data_dict)
    df.to_csv(target, index=False, mode='a', header=False)
    return df

# add request number
def generate_request_number(source="./db/response.csv"):
    try:
        request_numbers = pd.read_csv(source)['requestNumber']
    except:
        reset_response_csv()
        request_numbers = pd.read_csv(source)['requestNumber']
        
    generated = request_numbers.max() + 1
    if pd.isna(generated):
        # na + 1 = na
        generated = 0
    return generated

# %%
import json

def request_video(youtube, video_id_list):
    '''
    Order might matter. Instead of writing to file in the request loop, could save the metadata and responses into a list (in-memory). Then, after the loop, save everything to file.
    For now, just toss everything in the request loop.
    
    Note that some videos are private, so YouTube won't hand over the data for those videos.
    If you ask for it, `items` will be empty.
    '''
    
    response_list = []
    videos_requested = 0
    for start_index in range(0, len(video_id_list), 50):
        id_chunk = list(video_id_list)[start_index:(start_index + 50)]
        params = {
            "part": "contentDetails,id,liveStreamingDetails,localizations,player,recordingDetails,snippet,statistics,status,topicDetails",
            "id": ','.join(id_chunk),
            "maxResults": 50
        }
        request = youtube.videos().list(**params)
        request_number = generate_request_number()
        
        time_sent = get_current_time()
        response = request.execute()
        time_received = get_current_time()
        
        # log to ./db/response.csv
        md = {}
        md["requestNumber"] = request_number
        md["timeSent"] = time_sent
        md["timeReceived"] = time_received
        md["params"] = {**params}
        append_response_csv(md)
        
        # log to raw, a directory of jsons. save the conversion from json to csv in the transformation stage.
        response["requestNumber"] = request_number
        with open(f"./raw/{response['requestNumber']}.json", "w") as fp:
            json.dump(response, fp)
        
        response_list.append(response)
        
        videos_requested += len(id_chunk)
        print(f"{videos_requested}/{len(video_id_list)} ({round(videos_requested / len(video_id_list) * 100, 2)}%)", end='\r')
    
    # thinking about returning a list of responses
    return response_list

# %%
import api_key

youtube = api_key.get_youtube()
df = read_playlist_csv()
video_ids = df['snippet.resourceId.videoId']
r_list = request_video(youtube, video_ids)
# Out:
# 2182/2182 (100.0%)

# %%
r_list
# Out:
# [{'kind': 'youtube#videoListResponse',
#   'etag': 'YIUPVpqNjppyCWOZfL-19bLb7uk',
#   'items': [],
#   'pageInfo': {'totalResults': 0, 'resultsPerPage': 0},
#   'requestNumber': 3}]

# %% [markdown]
# # Transformation

# %%
def video_response_to_df(video_dict):
    df = pd.json_normalize(
        video_dict,
        record_path='items',
        meta=["kind", "etag", ["pageInfo", "totalResults"], ["pageInfo", "resultsPerPage"], "requestNumber"],
        meta_prefix="meta.",
        errors="ignore"
    )
    return df

df = video_response_to_df(r_list)
df.head(2)
# Out:
#             kind                         etag           id  \
# 0  youtube#video  q07ah-xiaLF9_bENqSDbu-Ud3Fw  -UE2gzTtHxo
# 1  youtube#video  36FNaLbUX-iC-hFgAzv7AEpRTlg  yb6vAQ2Tir4
#
#     snippet.publishedAt         snippet.channelId  \
# 0  2016-04-30T00:30:01Z  UCKy1dAqELo0zrOtPkf0eTMw
# 1  2016-04-27T02:00:01Z  UCKy1dAqELo0zrOtPkf0eTMw
#
#                                    snippet.title  \
# 0                              Alienation Review
# 1  The Walking Dead: Michonne - Episode 3 Review
#
#                                  snippet.description  \
# 0  Housemarque's follow-up to Dead Nation is fast...
# 1  The third and final episode of Michonne's jour...
#
#                    snippet.thumbnails.default.url  \
# 0  https://i.ytimg.com/vi/-UE2gzTtHxo/default.jpg
# 1  https://i.ytimg.com/vi/yb6vAQ2Tir4/default.jpg
#
#    snippet.thumbnails.default.width  snippet.thumbnails.default.height  ...  \
# 0                               120                                 90  ...
# 1                               120                                 90  ...
#
#   contentDetails.contentRating.ytRating  liveStreamingDetails.actualStartTime  \
# 0                                   NaN                                   NaN
# 1                                   NaN                                   NaN
#
#    liveStreamingDetails.actualEndTime liveStreamingDetails.scheduledStartTime  \
# 0                                 NaN                                     NaN
# 1                                 NaN                                     NaN
#
#    liveStreamingDetails.scheduledEndTime                  meta.kind  \
# 0                                    NaN  youtube#videoListResponse
# 1                                    NaN  youtube#videoListResponse
#
#                      meta.etag  meta.pageInfo.totalResults  \
# 0  ZhOVBxwEbaOQHAdL-UyWLjX7sgY                          50
# 1  ZhOVBxwEbaOQHAdL-UyWLjX7sgY                          50
#
#    meta.pageInfo.resultsPerPage meta.requestNumber
# 0                            50                  0
# 1                            50                  0
#
# [2 rows x 57 columns]

# %%
def reset_video_csv(target="./db/video.csv"):
    cols = ['kind',
 'etag',
 'id',
 'snippet.publishedAt',
 'snippet.channelId',
 'snippet.title',
 'snippet.description',
 'snippet.thumbnails.default.url',
 'snippet.thumbnails.default.width',
 'snippet.thumbnails.default.height',
 'snippet.thumbnails.medium.url',
 'snippet.thumbnails.medium.width',
 'snippet.thumbnails.medium.height',
 'snippet.thumbnails.high.url',
 'snippet.thumbnails.high.width',
 'snippet.thumbnails.high.height',
 'snippet.thumbnails.standard.url',
 'snippet.thumbnails.standard.width',
 'snippet.thumbnails.standard.height',
 'snippet.thumbnails.maxres.url',
 'snippet.thumbnails.maxres.width',
 'snippet.thumbnails.maxres.height',
 'snippet.channelTitle',
 'snippet.tags',
 'snippet.categoryId',
 'snippet.liveBroadcastContent',
 'snippet.localized.title',
 'snippet.localized.description',
 'contentDetails.duration',
 'contentDetails.dimension',
 'contentDetails.definition',
 'contentDetails.caption',
 'contentDetails.licensedContent',
 'contentDetails.projection',
 'status.uploadStatus',
 'status.privacyStatus',
 'status.license',
 'status.embeddable',
 'status.publicStatsViewable',
 'status.madeForKids',
 'statistics.viewCount',
 'statistics.likeCount',
 'statistics.favoriteCount',
 'statistics.commentCount',
 'player.embedHtml',
 'topicDetails.topicCategories',
 'snippet.defaultAudioLanguage',
 'contentDetails.contentRating.ytRating',
 'liveStreamingDetails.actualStartTime',
 'liveStreamingDetails.actualEndTime',
 'liveStreamingDetails.scheduledStartTime',
 'liveStreamingDetails.scheduledEndTime',
 'meta.kind',
 'meta.etag',
 'meta.pageInfo.totalResults',
 'meta.pageInfo.resultsPerPage',
 'meta.requestNumber']
    pd.DataFrame(columns=cols).to_csv(target, index=False)
    return cols

def gather_jsons_to_df(directory="./raw"):
    big_df = pd.DataFrame()
    to_concat = [big_df]
    
    json_files = Path(directory).glob("*.json")
    for j in json_files:
        df = json_to_df(j)
        to_concat.append(df)
        
    big_df = pd.concat(to_concat, axis=0)
    return big_df

def json_to_df(path):
    with open(path, 'r') as fp:
        response_dict = json.load(fp)
        df = video_response_to_df(response_dict)
        
    return df

# %%
import shutil

def consume_raw(directory='./raw'):
    json_df = gather_jsons_to_df(directory)
    try:
        old_df = pd.read_csv("./db/video.csv")
    except:
        reset_video_csv()
        old_df = pd.read_csv("./db/video.csv")
        
    combined_df = pd.concat([old_df, json_df], axis=0)
    combined_df = combined_df.drop_duplicates('id')
    combined_df.to_csv("./db/video.csv", index=False, header=True)
    
    json_files = Path(directory).glob("*.json")
    for j in json_files:
        shutil.move(j, "./consumed")
    
    return list(json_files)

# %%
cols = reset_video_csv()

# %%
json_files = consume_raw()

# %%
video_df = pd.read_csv("./db/video.csv")
video_df.head(5)
# Out:
#             kind                         etag           id  \
# 0  youtube#video  6MOCAIN4LYZZvDIVus9QTrl9HTk  h663A9inOgw
# 1  youtube#video  Yrv4eQfwEXrNPGPUzk4n5eDcQw4  _BMPpDZu7dk
# 2  youtube#video  43V5iVRxKoECu6btkD6NJiVywQA  KJxi30ZAXeM
# 3  youtube#video  vy6TZqRhO6eVcN0Lu-sRe1dAcds  dk12WzLRD2I
# 4  youtube#video  kHy-4ctOLBAj9L6XH76pZh7X4qk  maGhZ9kY12M
#
#     snippet.publishedAt         snippet.channelId  \
# 0  2017-03-02T09:00:05Z  UCKy1dAqELo0zrOtPkf0eTMw
# 1  2017-03-01T14:08:45Z  UCKy1dAqELo0zrOtPkf0eTMw
# 2  2017-02-28T21:24:07Z  UCKy1dAqELo0zrOtPkf0eTMw
# 3  2017-02-22T02:07:48Z  UCKy1dAqELo0zrOtPkf0eTMw
# 4  2017-02-22T01:00:03Z  UCKy1dAqELo0zrOtPkf0eTMw
#
#                                        snippet.title  \
# 0  Super Bomberman R (Nintendo Switch) Review Imp...
# 1                 Nintendo Switch Review In Progress
# 2                  Torment: Tides of Numenera Review
# 3                                 Halo Wars 2 Review
# 4            Berserk and the Band of the Hawk Review
#
#                                  snippet.description  \
# 0  Here's what we think of Bomberman's Nintendo S...
# 1  Here's what we think so far about Nintendo's a...
# 2  Torment: Tides of Numenera reviewed by Leif Jo...
# 3  Halo Wars 2 reviewed on Xbox One and PC by Dan...
# 4  Berserk and the Band of the Hawk reviewed by C...
#
#                    snippet.thumbnails.default.url  \
# 0  https://i.ytimg.com/vi/h663A9inOgw/default.jpg
# 1  https://i.ytimg.com/vi/_BMPpDZu7dk/default.jpg
# 2  https://i.ytimg.com/vi/KJxi30ZAXeM/default.jpg
# 3  https://i.ytimg.com/vi/dk12WzLRD2I/default.jpg
# 4  https://i.ytimg.com/vi/maGhZ9kY12M/default.jpg
#
#    snippet.thumbnails.default.width  snippet.thumbnails.default.height  ...  \
# 0                               120                                 90  ...
# 1                               120                                 90  ...
# 2                               120                                 90  ...
# 3                               120                                 90  ...
# 4                               120                                 90  ...
#
#   contentDetails.contentRating.ytRating  liveStreamingDetails.actualStartTime  \
# 0                                   NaN                                   NaN
# 1                                   NaN                                   NaN
# 2                                   NaN                                   NaN
# 3                                   NaN                                   NaN
# 4                                   NaN                                   NaN
#
#    liveStreamingDetails.actualEndTime liveStreamingDetails.scheduledStartTime  \
# 0                                 NaN                                     NaN
# 1                                 NaN                                     NaN
# 2                                 NaN                                     NaN
# 3                                 NaN                                     NaN
# 4                                 NaN                                     NaN
#
#    liveStreamingDetails.scheduledEndTime                  meta.kind  \
# 0                                    NaN  youtube#videoListResponse
# 1                                    NaN  youtube#videoListResponse
# 2                                    NaN  youtube#videoListResponse
# 3                                    NaN  youtube#videoListResponse
# 4                                    NaN  youtube#videoListResponse
#
#                      meta.etag  meta.pageInfo.totalResults  \
# 0  Q4q8qHbBwBSWTe5p2I6ucBsuqZs                          50
# 1  Q4q8qHbBwBSWTe5p2I6ucBsuqZs                          50
# 2  Q4q8qHbBwBSWTe5p2I6ucBsuqZs                          50
# 3  Q4q8qHbBwBSWTe5p2I6ucBsuqZs                          50
# 4  Q4q8qHbBwBSWTe5p2I6ucBsuqZs                          50
#
#    meta.pageInfo.resultsPerPage meta.requestNumber
# 0                            50                 28
# 1                            50                 28
# 2                            50                 28
# 3                            50                 28
# 4                            50                 28
#
# [5 rows x 57 columns]

# %%
video_df.shape
# Out:
# (2159, 57)

# %% [markdown]
# #### Testing Grounds

# %% [markdown]
# ##### Test:
#
# What if send video id of a private video?

# %%
# df[df['snippet.title'].str.lower() == 'private video']
private_video_id = 'B6BCKY_KTv0' # example of private video
df = read_playlist_csv()
df[df['snippet.resourceId.videoId'] == private_video_id]
# Out:
#                     kind                         etag  \
# 73  youtube#playlistItem  NSxb1i0FeP3_eTmkK0YFjHdX8nE
#
#                                                    id   snippet.publishedAt  \
# 73  UExyYUZid0NvaXNKQlRsMG9YbjhVb1VhbTVIWFdVWjdFUy...  2016-01-20T18:00:11Z
#
#            snippet.channelId  snippet.title     snippet.description  \
# 73  UCKy1dAqELo0zrOtPkf0eTMw  Private video  This video is private.
#
#    snippet.channelTitle                  snippet.playlistId  snippet.position  \
# 73                  IGN  PLraFbwCoisJBTl0oXn8UoUam5HXWUZ7ES              1673
#
#     ... snippet.thumbnails.maxres.height snippet.videoOwnerChannelTitle  \
# 73  ...                              NaN                            NaN
#
#    snippet.videoOwnerChannelId contentDetails.videoPublishedAt  \
# 73                         NaN                             NaN
#
#                            meta.kind                    meta.etag  \
# 73  youtube#playlistItemListResponse  FVDW-bzKQHoVgTXjeSJrb_3pLl4
#
#                                    meta.nextPageToken  \
# 73  EAAaMVBUOkNLUU5JaEJFTjBORk5Ua3pSamczTmtZeFJqY3...
#
#    meta.pageInfo.totalResults  meta.pageInfo.resultsPerPage  \
# 73                       2182                            50
#
#     meta.requestNumber
# 73                  79
#
# [1 rows x 38 columns]

# %%
r_list = request_video(youtube, [video_ids[0], 'B6BCKY_KTv0'])
len(r_list[0]['items'])
# Out:
# 2/2 (100.0%)
# 1

# %% [markdown]
# Private videos do not get added as an item when returning a response.
